# %%
testing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9801739daae4> in <module>
# ----> 1 testing
#
# NameError: name 'testing' is not defined

# %%
# !git pull origin master
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/ximtra/hello-world
#  * branch            master     -> FETCH_HEAD
#    e912e03..7dfc1bb  master     -> origin/master
# Updating e912e03..7dfc1bb
# Fast-forward
#  testing | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 testing

# %%
# !git push origin master *
# Out:
# error: src refspec README.md does not match any.
# error: src refspec testing does not match any.
# error: src refspec Untitled.ipynb does not match any.
# error: failed to push some refs to 'https://github.com/ximtra/hello-world.git'
